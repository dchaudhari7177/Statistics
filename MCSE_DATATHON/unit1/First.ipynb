# %%
import pandas as pd

titanic_data = pd.read_csv('Titanic-Dataset.csv')

print(titanic_data.head())

data = {
    'Feature': ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
    'Data Type': ['Nominal', 'Nominal', 'Ordinal', 'Nominal', 'Nominal', 'Ratio', 'Ratio', 'Ratio', 'Nominal', 'Ratio', 'Nominal', 'Nominal'],
    'Rationale': [
        'Unique identifier for each passenger, no inherent order.',
        'Binary variable indicating survival (0 = no, 1 = yes). No inherent order, categorical.',
        'Passenger class with inherent order (1 < 2 < 3).',
        'Names are unique identifiers, no inherent order.',
        'Categories of gender (male, female) with no inherent order.',
        'Continuous feature with a true zero, making it a ratio.',
        'Countable numerical feature with a meaningful zero, ratio.',
        'Countable numerical feature with a meaningful zero, ratio.',
        'Ticket number, an identifier with no inherent order.',
        'Continuous feature with a true zero, making it a ratio.',
        'Cabin number, an identifier with no inherent order.',
        'Categorical feature representing ports of embarkation (C, Q, S) with no inherent order.'
    ]
}

df = pd.DataFrame(data)

df
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# ...
